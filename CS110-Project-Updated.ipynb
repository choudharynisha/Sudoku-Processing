// %%
int[][] p = new int[9][9]; // 2-D array for puzzle

boolean p1; // puzzle 1
boolean p2; // puzzle 2
boolean p3; // puzzle 3
boolean p4; // puzzle 4
boolean p5; // puzzle 5
boolean p6; // puzzle 6
boolean p7; // puzzle 7
boolean p8; // puzzle 8
boolean p9; // puzzle 9
boolean p10; // puzzle 10
boolean p11; // puzzle 11
boolean p12; // puzzle 12

int row; // the selected row
int col; // the selected column
int num; // the number that the user enters

void check1() {
    strokeWeight(1);
    textSize(20);
    
    boolean right = true; // all answers assumed to be initially true
    
    p[0][5] = 3;
    p[0][8] = 6;
    p[1][3] = 7;
    p[1][8] = 9;
    p[2][2] = 4;
    p[2][4] = 6;
    p[2][7] = 8;
    p[2][8] = 2;
    p[3][4] = 9;
    p[3][7] = 7;
    p[4][1] = 1;
    p[4][2] = 6;
    p[4][6] = 8;
    p[4][7] = 5;
    p[5][1] = 2;
    p[5][4] = 3;
    p[6][0] = 2;
    p[6][1] = 8;
    p[6][4] = 5;
    p[6][6] = 6;
    p[7][0] = 3;
    p[7][5] = 8;
    p[8][0] = 7;
    p[8][3] = 1;
    
    if(p[0][0] != 0 && p[0][0] != 5) {
        fill(255, 102, 102);
        rect(20, 20, 50, 50);
        
        fill(255, 0, 0);
        right = false;
    }
    
    if(p[0][1] != 0 && p[0][1] != 9) {
        fill(255, 102, 102);
        rect(70, 20, 50, 50);
        
        fill(255, 0, 0);
        right = false;
    }
    
    if(p[0][2] != 0 && p[0][2] != 2) {
        fill(255, 102, 102);
        rect(120, 20, 50, 50);
        
        fill(255, 0, 0);
        right = false;
    }
    
    if(p[0][3] != 0 && p[0][3] != 4) {
        fill(255, 102, 102);
        rect(170, 20, 50, 50);
        
        right = false;
    }
    
    if(p[0][4] != 0 && p[0][4] != 8) {
        fill(255, 102, 102);
        rect(220, 20, 50, 50);
        
        right = false;
    }
    
    if(p[0][6] != 0 && p[0][6] != 7) {
        fill(255, 102, 102);
        rect(320, 20, 50, 50);
        
        right = false;
    }
    
    if(p[0][7] != 0 && p[0][7] != 1) {
        fill(255, 102, 102);
        rect(370, 20, 50, 50);
        
        right = false;
    }
    
    if(p[1][0] != 0 && p[1][0] != 6) {
        fill(255, 102, 102);
        rect(20, 70, 50, 50);
        
        right = false;
    }
    
    if(p[1][1] != 0 && p[1][1] != 3) {
        fill(255, 102, 102);
        rect(70, 70, 50, 50);
        
        right = false;
    }
    
    if(p[1][2] != 0 && p[1][2] != 8) {
        fill(255, 102, 102);
        rect(120, 70, 50, 50);
        
        right = false;
    }
    
    if(p[1][3] != 7) {
        p[1][3] = 7;
    }
    
    if(p[1][4] != 0 && p[1][4] != 1) {
        fill(255, 102, 102);
        rect(220, 70, 50, 50);
        
        right = false;
    }
    
    if(p[1][5] != 0 && p[1][5] != 2) {
        fill(255, 102, 102);
        rect(270, 70, 50, 50);
        
        right = false;
    }
    
    if(p[1][6] != 0 && p[1][6] != 5) {
        fill(255, 102, 102);
        rect(320, 70, 50, 50);
        
        right = false;
    }
    
    if(p[1][7] != 0 && p[1][7] != 4) {
        fill(255, 102, 102);
        rect(370, 70, 50, 50);
        
        right = false;
    }
    
    if(p[1][8] != 9) {
        p[1][8] = 9;
    }
    
    if(p[2][0] != 0 && p[2][0] != 1) {
        fill(255, 102, 102);
        rect(20, 120, 50, 50);
        
        right = false;
    }
    
    if(p[2][1] != 0 && p[2][1] != 7) {
        fill(255, 102, 102);
        rect(70, 120, 50, 50);
        
        right = false;
    }
    
    if(p[2][3] != 0 && p[2][3] != 9) {
        fill(255, 102, 102);
        rect(170, 120, 50, 50);
        
        right = false;
    }
    
    if(p[2][5] != 0 && p[2][5] != 5) {
        fill(255, 102, 102);
        rect(270, 120, 50, 50);
        
        right = false;
    }
    
    if(p[2][6] != 0 && p[2][6] != 3) {
        fill(255, 102, 102);
        rect(320, 120, 50, 50);
        
        right = false;
    }
    
    if(p[3][0] != 0 && p[3][0] != 4) {
        fill(255, 102, 102);
        rect(20, 170, 50, 50);
        
        right = false;
    }
    
    if(p[3][1] != 0 && p[3][1] != 5) {
        fill(255, 102, 102);
        rect(70, 170, 50, 50);
        
        right = false;
    }
    
    if(p[3][2] != 0 && p[3][2] != 3) {
        fill(255, 102, 102);
        rect(120, 170, 50, 50);
        
        right = false;
    }
    
    if(p[3][3] != 0 && p[3][3] != 8) {
        fill(255, 102, 102);
        rect(170, 170, 50, 50);
        
        right = false;
    }
    
    if(p[3][5] != 0 && p[3][5] != 6) {
        fill(255, 102, 102);
        rect(270, 170, 50, 50);
        
        right = false;
    }
    
    if(p[3][6] != 0 && p[3][6] != 2) {
        fill(255, 102, 102);
        rect(320, 170, 50, 50);
        
        right = false;
    }
    
    if(p[3][8] != 0 && p[3][8] != 1) {
        fill(255, 102, 102);
        rect(420, 170, 50, 50);
        
        right = false;
    }
    
    if(p[4][0] != 0 && p[4][0] != 9) {
        fill(255, 102, 102);
        rect(20, 220, 50, 50);
        
        right = false;
    }
    
    if(p[4][3] != 0 && p[4][3] != 2) {
        fill(255, 102, 102);
        rect(170, 220, 50, 50);
        
        right = false;
    }
    
    if(p[4][4] != 0 && p[4][4] != 4) {
        fill(255, 102, 102);
        rect(220, 220, 50, 50);
        
        right = false;
    }
    
    if(p[4][5] != 0 && p[4][5] != 7) {
        fill(255, 102, 102);
        rect(270, 220, 50, 50);
        
        right = false;
    }
    
    if(p[4][8] != 0 && p[4][8] != 3) {
        fill(255, 102, 102);
        rect(420, 220, 50, 50);
        
        right = false;
    }
    
    if(p[5][0] != 0 && p[5][0] != 8) {
        fill(255, 102, 102);
        rect(20, 270, 50, 50);
        
        right = false;
    }
    
    if(p[5][2] != 0 && p[5][2] != 7) {
        fill(255, 102, 102);
        rect(120, 270, 50, 50);
        
        right = false;
    }
    
    if(p[5][3] != 0 && p[5][3] != 5) {
        fill(255, 102, 102);
        rect(170, 270, 50, 50);
        
        right = false;
    }
    
    if(p[5][5] != 0 && p[5][5] != 1) {
        fill(255, 102, 102);
        rect(270, 270, 50, 50);
        
        right = false;
    }
    
    if(p[5][6] != 0 && p[5][6] != 9) {
        fill(255, 102, 102);
        rect(320, 270, 50, 50);
        
        right = false;
    }
    
    if(p[5][7] != 0 && p[5][7] != 6) {
        fill(255, 102, 102);
        rect(370, 270, 50, 50);
        
        right = false;
    }
    
    if(p[5][8] != 0 && p[5][8] != 4) {
        fill(255, 102, 102);
        rect(420, 270, 50, 50);
        
        right = false;
    }
    
    if(p[6][2] != 0 && p[6][2] != 1) {
        fill(255, 102, 102);
        rect(120, 320, 50, 50);
        
        right = false;
    }
    
    if(p[6][3] != 0 && p[6][3] != 3) {
        fill(255, 102, 102);
        rect(170, 320, 50, 50);
        
        right = false;
    }
    
    if(p[6][5] != 0 && p[6][5] != 4) {
        fill(255, 102, 102);
        rect(270, 320, 50, 50);
        
        right = false;
    }
    
    if(p[6][7] != 0 && p[6][7] != 9) {
        fill(255, 102, 102);
        rect(370, 320, 50, 50);
        
        right = false;
    }
    
    if(p[6][8] != 0 && p[6][8] != 7) {
        fill(255, 102, 102);
        rect(420, 320, 50, 50);
        
        right = false;
    }
    
    if(p[7][1] != 0 && p[7][1] != 4) {
        fill(255, 102, 102);
        rect(70, 370, 50, 50);
        
        right = false;
    }
    
    if(p[7][2] != 0 && p[7][2] != 9) {
        fill(255, 102, 102);
        rect(120, 370, 50, 50);
        
        right = false;
    }
    
    if(p[7][3] != 0 && p[7][3] != 6) {
        fill(255, 102, 102);
        rect(170, 370, 50, 50);
        
        right = false;
    }
    
    if(p[7][4] != 0 && p[7][4] != 7) {
        fill(255, 102, 102);
        rect(220, 370, 50, 50);
        
        right = false;
    }
    
    if(p[7][6] != 0 && p[7][6] != 1) {
        fill(255, 102, 102);
        rect(320, 370, 50, 50);
        
        right = false;
    }
    
    if(p[7][7] != 0 && p[7][7] != 2) {
        fill(255, 102, 102);
        rect(370, 370, 50, 50);
        
        right = false;
    }
    
    if(p[7][8] != 0 && p[7][8] != 5) {
        fill(255, 102, 102);
        rect(420, 370, 50, 50);
        
        right = false;
    }
    
    if(p[8][1] != 0 && p[8][1] != 6) {
        fill(255, 102, 102);
        rect(70, 420, 50, 50);
        
        right = false;
    }
    
    if(p[8][2] != 0 && p[8][2] != 5) {
        fill(255, 102, 102);
        rect(120, 420, 50, 50);
        
        right = false;
    }
    
    if(p[8][4] != 0 && p[8][4] != 2) {
        fill(255, 102, 102);
        rect(220, 420, 50, 50);
        
        right = false;
    }
    
    if(p[8][5] != 0 && p[8][5] != 9) {
        fill(255, 102, 102);
        rect(270, 420, 50, 50);
        
        right = false;
    }
    
    if(p[8][6] != 0 && p[8][6] != 4) {
        fill(255, 102, 102);
        rect(320, 420, 50, 50);
        
        right = false;
    }
    
    if(p[8][7] != 0 && p[8][7] != 3) {
        fill(255, 102, 102);
        rect(370, 420, 50, 50);
        
        right = false;
    }
    
    if(p[8][8] != 0 && p[8][8] != 8) {
        fill(255, 102, 102);
        rect(420, 420, 50, 50);
        
        right = false;
    }
    
    if(!right) {
        fill(255, 0, 0);
        text("Something isn't right in the highlighted cell(s).", 500, 400);
    }
}

void check2() {
    strokeWeight(1);
    textSize(20);
    
    boolean right = true; // all answers assumed to be initially true
    
    p[0][4] = 6;
    p[0][5] = 1;
    p[0][8] = 5;
    p[1][0] = 8;
    p[1][4] = 5;
    p[2][6] = 8;
    p[2][7] = 4;
    p[2][8] = 7;
    p[3][1] = 5;
    p[3][6] = 9;
    p[4][0] = 6;
    p[4][3] = 9;
    p[4][5] = 4;
    p[4][8] = 8;
    p[5][2] = 3;
    p[5][7] = 1;
    p[6][0] = 7;
    p[6][1] = 9;
    p[6][2] = 1;
    p[7][4] = 8;
    p[7][8] = 2;
    p[8][0] = 5;
    p[8][3] = 7;
    p[8][4] = 3;
    
    if(!right) {
        fill(255, 0, 0);
        text("Something isn't right in the highlighted cell(s).", 500, 400);
    }
}

void check3() {
    strokeWeight(1);
    textSize(20);
    
    boolean right = true; // all answers assumed to be initially true
    
    p[0][5] = 1;
    p[0][6] = 2;
    p[0][7] = 6;
    p[1][6] = 7;
    p[2][2] = 5;
    p[2][4] = 3;
    p[2][7] = 8;
    p[3][0] = 2;
    p[3][1] = 3;
    p[3][2] = 6;
    p[3][3] = 4;
    p[3][7] = 9;
    p[4][3] = 6;
    p[4][5] = 9;
    p[5][1] = 8;
    p[5][5] = 2;
    p[5][6] = 4;
    p[5][7] = 7;
    p[5][8] = 6;
    p[6][1] = 5;
    p[6][4] = 4;
    p[6][6] = 1;
    p[7][2] = 3;
    p[8][1] = 9;
    p[8][2] = 8;
    p[8][3] = 7;
    
    if(!right) {
        fill(255, 0, 0);
        text("Something isn't right in the highlighted cell(s).", 500, 400);
    }
}

void check4() {
    strokeWeight(1);
    textSize(20);
    
    boolean right = true; // all answers assumed to be initially true
    
    p[0][3] = 8;
    p[1][4] = 7;
    p[1][6] = 2;
    p[1][8] = 9;
    p[2][5] = 6;
    p[2][7] = 1;
    p[2][8] = 4;
    p[3][1] = 8;
    p[3][2] = 2;
    p[3][7] = 7;
    p[4][1] = 4;
    p[4][3] = 3;
    p[4][4] = 9;
    p[4][5] = 2;
    p[4][7] = 8;
    p[5][1] = 5;
    p[5][6] = 9;
    p[5][7] = 2;
    p[6][0] = 6;
    p[6][1] = 3;
    p[6][3] = 5;
    p[7][0] = 5;
    p[7][2] = 9;
    p[7][4] = 1;
    p[8][5] = 4;
    
    if(p[0][0] != 0 && p[0][0] != 2) {
        fill(255, 102, 102);
        rect(22, 22, 46, 46);
        
        right = false;
    }
    
    if(p[0][1] != 0 && p[0][1] != 1) {
        fill(255, 102, 102);
        rect(72, 22, 46, 46);
        
        right = false;
    }
    
    if(p[0][2] != 0 && p[0][2] != 3) {
        fill(255, 102, 102);
        rect(122, 22, 46, 46);
        
        right = false;
    }
    
    if(p[0][4] != 0 && p[0][4] != 4) {
        fill(255, 102, 102);
        rect(220, 20, 50, 50);
        
        right = false;
    }
    
    if(p[0][5] != 0 && p[0][5] != 9) {
        fill(255, 102, 102);
        rect(270, 20, 50, 50);
        
        right = false;
    }
    
    if(p[0][6] != 0 && p[0][6] != 7) {
        fill(255, 102, 102);
        rect(320, 20, 50, 50);
        
        right = false;
    }
    
    if(p[0][7] != 0 && p[0][7] != 6) {
        fill(255, 102, 102);
        rect(370, 20, 50, 50);
        
        right = false;
    }
    
    if(p[0][8] != 0 && p[0][8] != 5) {
        fill(255, 102, 102);
        rect(420, 20, 50, 50);
        
        right = false;
    }
    
    if(p[1][0] != 0 && p[1][0] != 4) {
        fill(255, 102, 102);
        rect(20, 70, 50, 50);
        
        right = false;
    }
    
    if(p[1][1] != 0 && p[1][1] != 6) {
        fill(255, 102, 102);
        rect(70, 70, 50, 50);
        
        right = false;
    }
    
    if(p[1][2] != 0 && p[1][2] != 8) {
        fill(255, 102, 102);
        rect(120, 70, 50, 50);
        
        right = false;
    }
    
    if(p[1][3] != 0 && p[1][3] != 1) {
        fill(255, 102, 102);
        rect(170, 70, 50, 50);
        
        right = false;
    }
    
    if(p[1][5] != 0 && p[1][5] != 5) {
        fill(255, 102, 102);
        rect(270, 70, 50, 50);
        
        right = false;
    }
    
    if(p[1][7] != 0 && p[1][7] != 3) {
        fill(255, 102, 102);
        rect(370, 70, 50, 50);
        
        right = false;
    }
    
    if(p[2][0] != 0 && p[2][0] != 7) {
        fill(255, 102, 102);
        rect(20, 120, 50, 50);
        
        right = false;
    }
    
    if(p[2][1] != 0 && p[2][1] != 9) {
        fill(255, 102, 102);
        rect(70, 120, 50, 50);
        
        right = false;
    }
    
    if(p[2][2] != 0 && p[2][2] != 5) {
        fill(255, 102, 102);
        rect(120, 120, 50, 50);
        
        right = false;
    }
    
    if(p[2][3] != 0 && p[2][3] != 2) {
        fill(255, 102, 102);
        rect(170, 120, 50, 50);
        
        right = false;
    }
    
    if(p[2][4] != 0 && p[2][4] != 3) {
        fill(255, 102, 102);
        rect(220, 120, 50, 50);
        
        right = false;
    }
    
    if(p[2][6] != 0 && p[2][6] != 8) {
        fill(255, 102, 102);
        rect(320, 120, 50, 50);
        
        right = false;
    }
    
    if(p[3][0] != 0 && p[3][0] != 9) {
        fill(255, 102, 102);
        rect(20, 170, 50, 50);
        
        right = false;
    }
    
    if(p[3][3] != 0 && p[3][3] != 6) {
        fill(255, 102, 102);
        rect(170, 170, 50, 50);
        
        right = false;
    }
    
    if(p[3][4] != 0 && p[3][4] != 5) {
        fill(255, 102, 102);
        rect(220, 170, 50, 50);
        
        right = false;
    }
    
    if(p[3][5] != 0 && p[3][5] != 1) {
        fill(255, 102, 102);
        rect(270, 170, 50, 50);
        
        right = false;
    }
    
    if(p[3][6] != 0 && p[3][6] != 4) {
        fill(255, 102, 102);
        rect(320, 170, 50, 50);
        
        right = false;
    }
    
    if(p[3][8] != 0 && p[3][8] != 3) {
        fill(255, 102, 102);
        rect(420, 170, 50, 50);
        
        right = false;
    }
    
    if(p[4][0] != 0 && p[4][0] != 1) {
        fill(255, 102, 102);
        rect(20, 220, 50, 50);
        
        right = false;
    }
    
    if(p[4][2] != 0 && p[4][2] != 7) {
        fill(255, 102, 102);
        rect(120, 220, 50, 50);
        
        right = false;
    }
    
    if(p[4][6] != 0 && p[4][6] != 5) {
        fill(255, 102, 102);
        rect(320, 220, 50, 50);
        
        right = false;
    }
    
    if(p[4][8] != 0 && p[4][8] != 6) {
        fill(255, 102, 102);
        rect(420, 220, 50, 50);
        
        right = false;
    }
    
    if(p[5][0] != 0 && p[5][0] != 3) {
        fill(255, 102, 102);
        rect(20, 270, 50, 50);
        
        right = false;
    }
    
    if(p[5][2] != 0 && p[5][2] != 6) {
        fill(255, 102, 102);
        rect(120, 270, 50, 50);
        
        right = false;
    }
    
    if(p[5][3] != 0 && p[5][3] != 4) {
        fill(255, 102, 102);
        rect(170, 270, 50, 50);
        
        right = false;
    }
    
    if(p[5][4] != 0 && p[5][4] != 8) {
        fill(255, 102, 102);
        rect(220, 270, 50, 50);
        
        right = false;
    }
    
    if(p[5][5] != 0 && p[5][5] != 7) {
        fill(255, 102, 102);
        rect(270, 270, 50, 50);
        
        right = false;
    }
    
    if(p[5][8] != 0 && p[5][8] != 1) {
        fill(255, 102, 102);
        rect(420, 270, 50, 50);
        
        right = false;
    }
    
    if(p[6][2] != 0 && p[6][2] != 4) {
        fill(255, 102, 102);
        rect(120, 320, 50, 50);
        
        right = false;
    }
    
    if(p[6][4] != 0 && p[6][4] != 2) {
        fill(255, 102, 102);
        rect(220, 320, 50, 50);
        
        right = false;
    }
    
    if(p[6][5] != 0 && p[6][5] != 8) {
        fill(255, 102, 102);
        rect(270, 320, 50, 50);
        
        right = false;
    }
    
    if(p[6][6] != 0 && p[6][6] != 1) {
        fill(255, 102, 102);
        rect(320, 320, 50, 50);
        
        right = false;
    }
    
    if(p[6][7] != 0 && p[6][7] != 9) {
        fill(255, 102, 102);
        rect(370, 320, 50, 50);
        
        right = false;
    }
    
    if(p[6][8] != 0 && p[6][8] != 7) {
        fill(255, 102, 102);
        rect(420, 320, 50, 50);
        
        right = false;
    }
    
    if(p[7][1] != 0 && p[7][1] != 2) {
        fill(255, 102, 102);
        rect(70, 370, 50, 50);
        
        right = false;
    }
    
    if(p[7][3] != 0 && p[7][3] != 7) {
        fill(255, 102, 102);
        rect(170, 370, 50, 50);
        
        right = false;
    }
    
    if(p[7][5] != 0 && p[7][5] != 3) {
        fill(255, 102, 102);
        rect(270, 370, 50, 50);
        
        right = false;
    }
    
    if(p[7][6] != 0 && p[7][6] != 6) {
        fill(255, 102, 102);
        rect(320, 370, 50, 50);
        
        right = false;
    }
    
    if(p[7][7] != 0 && p[7][7] != 4) {
        fill(255, 102, 102);
        rect(370, 370, 50, 50);
        
        right = false;
    }
    
    if(p[7][8] != 0 && p[7][8] != 8) {
        fill(255, 102, 102);
        rect(420, 370, 50, 50);
        
        right = false;
    }
    
    if(p[8][0] != 0 && p[8][0] != 8) {
        fill(255, 102, 102);
        rect(20, 420, 50, 50);
        
        right = false;
    }
    
    if(p[8][1] != 0 && p[8][1] != 7) {
        fill(255, 102, 102);
        rect(70, 420, 50, 50);
        
        right = false;
    }
    
    if(p[8][2] != 0 && p[8][2] != 1) {
        fill(255, 102, 102);
        rect(120, 420, 50, 50);
        
        right = false;
    }
    
    if(p[8][3] != 0 && p[8][3] != 9) {
        fill(255, 102, 102);
        rect(170, 420, 50, 50);
        
        right = false;
    }
    
    if(p[8][4] != 0 && p[8][4] != 6) {
        fill(255, 102, 102);
        rect(220, 420, 50, 50);
        
        right = false;
    }
    
    if(p[8][6] != 0 && p[8][6] != 3) {
        fill(255, 102, 102);
        rect(320, 420, 50, 50);
        
        right = false;
    }
    
    if(p[8][7] != 0 && p[8][7] != 5) {
        fill(255, 102, 102);
        rect(370, 420, 50, 50);
        
        right = false;
    }
    
    if(p[8][8] != 0 && p[8][8] != 2) {
        fill(255, 102, 102);
        rect(420, 420, 50, 50);
        
        right = false;
    }
    
    if(!right) {
        fill(255, 0, 0);
        text("Something isn't right in the highlighted cell(s).", 500, 400);
    }
}

void check5() {
    strokeWeight(1);
    textSize(20);
    
    boolean right = true; // all answers assumed to be initially true
    
    p[0][1] = 9;
    p[0][2] = 5;
    p[0][4] = 3;
    p[0][5] = 6;
    p[1][0] = 4;
    p[2][0] = 1;
    p[2][3] = 8;
    p[2][4] = 5;
    p[2][6] = 6;
    p[2][7] = 7;
    p[3][0] = 2;
    p[3][2] = 1;
    p[4][0] = 9;
    p[4][1] = 5;
    p[4][7] = 8;
    p[4][8] = 6;
    p[5][6] = 2;
    p[5][8] = 1;
    p[6][1] = 7;
    p[6][2] = 8;
    p[6][4] = 9;
    p[6][5] = 1;
    p[6][8] = 4;
    p[7][8] = 3;
    p[8][3] = 2;
    p[8][4] = 8;
    p[8][6] = 9;
    p[8][7] = 6;
    
    if(p[0][0] != 0) {
        fill(255, 102, 102);
        
        right = false;
    }
    
    if(p[0][3] != 0) {
        fill(255, 102, 102);
        
        right = false;
    }
    
    if(p[0][5] != 0) {
        fill(255, 102, 102);
        
        right = false;
    }
    
    if(p[7][4] != 0) {
        fill(255, 102, 102);
        
        right = false;
    }
    
    if(p[7][5] != 0) {
        fill(255, 102, 102);
        
        right = false;
    }
    
    if(p[7][6] != 0) {
        fill(255, 102, 102);
        
        right = false;
    }
    
    if(p[7][7] != 0) {
        fill(255, 102, 102);
        
        right = false;
    }
    
    if(p[8][0] != 0) {
        fill(255, 102, 102);
        
        right = false;
    }
    
    if(p[8][1] != 0) {
        fill(255, 102, 102);
        
        right = false;
    }
    
    if(p[8][2] != 0) {
        fill(255, 102, 102);
        
        right = false;
    }
    
    if(p[8][5] != 0) {
        fill(255, 102, 102);
        
        right = false;
    }
    
    if(p[8][8] != 0) {
        fill(255, 102, 102);
        
        right = false;
    }
    
    if(!right) {
        fill(255, 0, 0);
        text("Something isn't right in the highlighted cell(s).", 500, 400);
    }
}

void check6() {
    strokeWeight(1);
    textSize(20);
    
    boolean right = true; // all answers assumed to be initially true
    
    p[0][0] = 6;
    p[0][3] = 5;
    p[0][4] = 3;
    p[0][8] = 7;
    p[1][0] = 4;
    p[1][2] = 1;
    p[1][7] = 2;
    p[2][1] = 9;
    p[2][3] = 1;
    p[2][5] = 4;
    p[3][3] = 8;
    p[3][7] = 9;
    p[4][0] = 7;
    p[4][2] = 4;
    p[4][6] = 8;
    p[4][8] = 2;
    p[5][1] = 8;
    p[5][5] = 5;
    p[6][3] = 9;
    p[6][5] = 1;
    p[6][7] = 3;
    p[7][1] = 3;
    p[7][6] = 9;
    p[7][8] = 5;
    p[8][0] = 1;
    p[8][4] = 5;
    p[8][5] = 3;
    p[8][8] = 6;
    
    if(!right) {
        fill(255, 0, 0);
        text("Something isn't right in the highlighted cell(s).", 500, 400);
    }
}

void check7() {
    strokeWeight(1);
    textSize(20);
    
    boolean right = true; // all answers assumed to be initially true
    
    p[0][0] = 7;
    p[0][4] = 2;
    p[0][5] = 9;
    p[0][7] = 1;
    p[1][0] = 2;
    p[1][4] = 4;
    p[1][5] = 8;
    p[2][0] = 8;
    p[2][1] = 3;
    p[2][4] = 6;
    p[2][6] = 2;
    p[3][0] = 4;
    p[3][2] = 9;
    p[3][5] = 6;
    p[3][8] = 8;
    p[4][0] = 3;
    p[4][8] = 1;
    p[5][0] = 5;
    p[5][3] = 4;
    p[5][6] = 6;
    p[5][8] = 3;
    p[6][2] = 2;
    p[6][4] = 9;
    p[6][7] = 3;
    p[6][8] = 7;
    p[7][3] = 6;
    p[7][4] = 1;
    p[7][8] = 2;
    p[8][1] = 4;
    p[8][3] = 2;
    p[8][4] = 7;
    p[8][8] = 6;
    
    if(p[0][1] != 0 && p[0][1] != 6) {
        fill(255, 102, 102);
        rect(70, 20, 50, 50);
        
        right = false;
    }
    
    if(p[0][2] != 0 && p[0][2] != 5) {
        fill(255, 102, 102);
        rect(120, 20, 50, 50);
        
        right = false;
    }
    
    if(p[0][3] != 0 && p[0][3] != 3) {
        fill(255, 102, 102);
        rect(170, 20, 50, 50);
        
        right = false;
    }
    
    if(p[0][6] != 0 && p[0][6] != 8) {
        fill(255, 102, 102);
        rect(320, 20, 50, 50);
        
        right = false;
    }
    
    if(p[0][8] != 0 && p[0][8] != 4) {
        fill(255, 102, 102);
        rect(420, 20, 50, 50);
        
        right = false;
    }
    
    if(p[1][1] != 0 && p[1][1] != 9) {
        fill(255, 102, 102);
        rect(70, 70, 50, 50);
        
        right = false;
    }
    
    if(p[1][2] != 0 && p[1][2] != 1) {
        fill(255, 102, 102);
        rect(120, 70, 50, 50);
        
        right = false;
    }
    
    if(p[1][3] != 0 && p[1][3] != 7) {
        fill(255, 102, 102);
        rect(170, 70, 50, 50);
        
        right = false;
    }
    
    if(p[1][6] != 0 && p[1][6] != 3) {
        fill(255, 102, 102);
        rect(320, 70, 50, 50);
        
        right = false;
    }
    
    if(p[1][7] != 0 && p[1][7] != 6) {
        fill(255, 102, 102);
        rect(370, 70, 50, 50);
        
        right = false;
    }
    
    if(p[1][8] != 0 && p[1][8] != 5) {
        fill(255, 102, 102);
        rect(420, 70, 50, 50);
        
        right = false;
    }
    
    if(p[2][2] != 0 && p[2][2] != 4) {
        fill(255, 102, 102);
        rect(120, 120, 50, 50);
        
        right = false;
    }
    
    if(p[2][3] != 0 && p[2][3] != 5) {
        fill(255, 102, 102);
        rect(170, 120, 50, 50);
        
        right = false;
    }
    
    if(p[2][5] != 0 && p[2][5] != 1) {
        fill(255, 102, 102);
        rect(270, 120, 50, 50);
        
        right = false;
    }
    
    if(p[2][7] != 0 && p[2][7] != 7) {
        fill(255, 102, 102);
        rect(370, 120, 50, 50);
        
        right = false;
    }
    
    if(p[2][8] != 0 && p[2][8] != 9) {
        fill(255, 102, 102);
        rect(420, 120, 50, 50);
        
        right = false;
    }
    
    if(p[3][1] != 0 && p[3][1] != 2) {
        fill(255, 102, 102);
        rect(70, 170, 50, 50);
        
        right = false;
    }
    
    if(p[3][3] != 0 && p[3][3] != 1) {
        fill(255, 102, 102);
        rect(170, 170, 50, 50);
        
        right = false;
    }
    
    if(p[3][4] != 0 && p[3][4] != 3) {
        fill(255, 102, 102);
        rect(220, 170, 50, 50);
        
        right = false;
    }
    
    if(p[3][6] != 0 && p[3][6] != 7) {
        fill(255, 102, 102);
        rect(320, 170, 50, 50);
        
        right = false;
    }
    
    if(p[3][7] != 0 && p[3][7] != 5) {
        fill(255, 102, 102);
        rect(370, 170, 50, 50);
        
        right = false;
    }
    
    if(p[4][1] != 0 && p[4][1] != 8) {
        fill(255, 102, 102);
        rect(70, 220, 50, 50);
        
        right = false;
    }
    
    if(p[4][2] != 0 && p[4][2] != 6) {
        fill(255, 102, 102);
        rect(120, 220, 50, 50);
        
        right = false;
    }
    
    if(p[4][3] != 0 && p[4][3] != 9) {
        fill(255, 102, 102);
        rect(170, 220, 50, 50);
        
        right = false;
    }
    
    if(p[4][4] != 0 && p[4][4] != 5) {
        fill(255, 102, 102);
        rect(220, 220, 50, 50);
        
        right = false;
    }
    
    if(p[4][5] != 0 && p[4][5] != 7) {
        fill(255, 102, 102);
        rect(270, 220, 50, 50);
        
        right = false;
    }
    
    if(p[4][6] != 0 && p[4][6] != 4) {
        fill(255, 102, 102);
        rect(320, 220, 50, 50);
        
        right = false;
    }
    
    if(p[4][7] != 0 && p[4][7] != 2) {
        fill(255, 102, 102);
        rect(370, 220, 50, 50);
        
        right = false;
    }
    
    if(p[5][1] != 0 && p[5][1] != 1) {
        fill(255, 102, 102);
        rect(70, 270, 50, 50);
        
        right = false;
    }
    
    if(p[5][2] != 0 && p[5][2] != 7) {
        fill(255, 102, 102);
        rect(120, 270, 50, 50);
        
        right = false;
    }
    
    if(p[5][4] != 0 && p[5][4] != 8) {
        fill(255, 102, 102);
        rect(220, 270, 50, 50);
        
        right = false;
    }
    
    if(p[5][5] != 0 && p[5][5] != 2) {
        fill(255, 102, 102);
        rect(270, 270, 50, 50);
        
        right = false;
    }
    if(p[5][7] != 0 && p[5][7] != 9) {
        fill(255, 102, 102);
        rect(370, 270, 50, 50);
        
        right = false;
    }
    
    if(p[6][0] != 0 && p[6][0] != 6) {
        fill(255, 102, 102);
        rect(20, 320, 50, 50);
        
        right = false;
    }
    
    if(p[6][1] != 0 && p[6][1] != 5) {
        fill(255, 102, 102);
        rect(70, 320, 50, 50);
        
        right = false;
    }
    
    if(p[6][3] != 0 && p[6][3] != 8) {
        fill(255, 102, 102);
        rect(170, 320, 50, 50);
        
        right = false;
    }
    
    if(p[6][5] != 0 && p[6][5] != 4) {
        fill(255, 102, 102);
        rect(270, 320, 50, 50);
        
        right = false;
    }
    
    if(p[6][6] != 0 && p[6][6] != 1) {
        fill(255, 102, 102);
        rect(320, 320, 50, 50);
        
        right = false;
    }
    
    if(p[7][0] != 0 && p[7][0] != 9) {
        fill(255, 102, 102);
        rect(20, 370, 50, 50);
        
        right = false;
    }
    
    if(p[7][1] != 0 && p[7][1] != 7) {
        fill(255, 102, 102);
        rect(70, 370, 50, 50);
        
        right = false;
    }
    
    if(p[7][2] != 0 && p[7][2] != 8) {
        fill(255, 102, 102);
        rect(120, 370, 50, 50);
        
        right = false;
    }
    
    if(p[7][5] != 0 && p[7][5] != 3) {
        fill(255, 102, 102);
        rect(270, 370, 50, 50);
        
        right = false;
    }
    
    if(p[7][6] != 0 && p[7][6] != 5) {
        fill(255, 102, 102);
        rect(320, 370, 50, 50);
        
        right = false;
    }
    
    if(p[7][7] != 0 && p[7][7] != 4) {
        fill(255, 102, 102);
        rect(370, 370, 50, 50);
        
        right = false;
    }
    
    if(p[8][0] != 0 && p[8][0] != 1) {
        fill(255, 102, 102);
        rect(20, 420, 50, 50);
        
        right = false;
    }
    
    if(p[8][2] != 0 && p[8][2] != 3) {
        fill(255, 102, 102);
        rect(120, 420, 50, 50);
        
        right = false;
    }
    
    if(p[8][5] != 0 && p[8][5] != 5) {
        fill(255, 102, 102);
        rect(270, 420, 50, 50);
        
        right = false;
    }
    
    if(p[8][6] != 0 && p[8][6] != 9) {
        fill(255, 102, 102);
        rect(320, 420, 50, 50);
        
        right = false;
    }
    
    if(p[8][7] != 0 && p[8][7] != 8) {
        fill(255, 102, 102);
        
        right = false;
    }
    
    if(!right) {
        fill(255, 0, 0);
        text("Something isn't right in the highlighted cell(s).", 500, 400);
    }
}

void check8() {
    strokeWeight(1);
    textSize(20);
    
    boolean right = true; // all answers assumed to be initially true
    
    p[0][1] = 4;
    p[0][2] = 1;
    p[0][6] = 8;
    p[1][7] = 5;
    p[2][1] = 2;
    p[2][3] = 7;
    p[2][5] = 8;
    p[2][6] = 4;
    p[2][7] = 9;
    p[3][0] = 2;
    p[3][4] = 7;
    p[3][5] = 9;
    p[3][7] = 6;
    p[4][2] = 9;
    p[4][3] = 5;
    p[4][4] = 3;
    p[4][5] = 2;
    p[4][6] = 1;
    p[5][1] = 3;
    p[5][3] = 6;
    p[5][4] = 1;
    p[5][8] = 9;
    p[6][1] = 1;
    p[6][2] = 2;
    p[6][3] = 4;
    p[6][5] = 5;
    p[6][7] = 8;
    p[7][1] = 8;
    p[8][2] = 5;
    p[8][5] = 1;
    p[8][7] = 4;
    
    if(!right) {
        fill(255, 0, 0);
        text("Something isn't right in the highlighted cell(s).", 500, 400);
    }
}

void check9() {
    strokeWeight(1);
    textSize(20);
    
    boolean right = true; // all answers assumed to be initially true
    
    p[0][3] = 6;
    p[0][7] = 3;
    p[0][1] = 1;
    p[1][8] = 1;
    p[1][3] = 5;
    p[1][6] = 2;
    p[1][7] = 9;
    p[2][3] = 2;
    p[2][6] = 6;
    p[3][0] = 5;
    p[3][4] = 6;
    p[3][5] = 2;
    p[4][1] = 6;
    p[4][2] = 9;
    p[4][4] = 8;
    p[4][6] = 7;
    p[4][7] = 4;
    p[5][3] = 3;
    p[5][4] = 7;
    p[5][8] = 5;
    p[6][2] = 6;
    p[6][5] = 9;
    p[7][1] = 3;
    p[7][2] = 4;
    p[7][5] = 1;
    p[7][7] = 5;
    p[8][0] = 7;
    p[8][1] = 5;
    p[8][5] = 6;
    
    if(!right) {
        fill(255, 0, 0);
        text("Something isn't right in the highlighted cell(s).", 500, 400);
    }
}

void check10() {
    strokeWeight(1);
    textSize(20);
    
    boolean right = true; // all answers assumed to be initially true
    
    p[0][2] = 7;
    p[0][5] = 6;
    p[1][1] = 3;
    p[1][5] = 5;
    p[2][0] = 5;
    p[2][1] = 6;
    p[2][2] = 4;
    p[2][4] = 1;
    p[2][7] = 2;
    p[3][0] = 2;
    p[3][3] = 5;
    p[3][4] = 6;
    p[3][8] = 7;
    p[4][2] = 5;
    p[4][6] = 6;
    p[5][0] = 8;
    p[5][4] = 7;
    p[5][5] = 2;
    p[5][8] = 3;
    p[6][1] = 8;
    p[6][4] = 5;
    p[6][6] = 7;
    p[6][7] = 9;
    p[6][8] = 4;
    p[7][3] = 9;
    p[7][7] = 3;
    p[8][3] = 3;
    p[8][6] = 5;
    
    if(!right) {
        fill(255, 0, 0);
        text("Something isn't right in the highlighted cell(s).", 500, 400);
    }
}

void check11() {
    strokeWeight(1);
    textSize(20);
    
    boolean right = true; // all answers assumed to be initially true
    
    p[0][5] = 2;
    p[0][6] = 5;
    p[0][7] = 8;
    p[1][0] = 1;
    p[1][2] = 2;
    p[1][8] = 7;
    p[2][3] = 9;
    p[2][4] = 7;
    p[2][5] = 3;
    p[2][6] = 2;
    p[2][7] = 6;
    p[3][3] = 5;
    p[3][4] = 8;
    p[3][5] = 4;
    p[3][6] = 3;
    p[3][7] = 1;
    p[4][0] = 2;
    p[4][3] = 6;
    p[4][5] = 7;
    p[4][8] = 5;
    p[5][1] = 5;
    p[5][2] = 8;
    p[5][3] = 2;
    p[5][4] = 1;
    p[5][5] = 9;
    p[6][1] = 7;
    p[6][2] = 9;
    p[6][3] = 8;
    p[6][4] = 2;
    p[6][5] = 5;
    p[7][0] = 5;
    p[7][6] = 7;
    p[7][8] = 9;
    p[8][1] = 2;
    p[8][2] = 3;
    p[8][3] = 7;
    
    if(!right) {
        fill(255, 0, 0);
        text("Something isn't right in the highlighted cell(s).", 500, 400);
    }
}

void check12() {
    strokeWeight(1);
    textSize(20);
    
    boolean right = true; // all answers assumed to be initially true
    
    p[0][0] = 5;
    p[0][4] = 9;
    p[0][5] = 4;
    p[0][6] = 6;
    p[0][7] = 3;
    p[1][0] = 1;
    p[1][1] = 7;
    p[1][3] = 3;
    p[1][4] = 6;
    p[1][6] = 9;
    p[1][8] = 2;
    p[2][1] = 3;
    p[2][4] = 2;
    p[2][7] = 4;
    p[3][0] = 7;
    p[3][8] = 8;
    p[4][0] = 2;
    p[4][3] = 7;
    p[4][5] = 1;
    p[4][8] = 6;
    p[5][0] = 3;
    p[5][8] = 4;
    p[6][1] = 9;
    p[6][4] = 7;
    p[6][7] = 2;
    p[7][0] = 4;
    p[7][2] = 1;
    p[7][4] = 8;
    p[7][5] = 9;
    p[7][7] = 6;
    p[7][8] = 3;
    p[8][1] = 2;
    p[8][2] = 7;
    p[8][3] = 4;
    p[8][4] = 1;
    p[8][8] = 9;
    
    if(p[0][1] != 0 && p[0][1] != 8) {
        fill(255, 102, 102);
        rect(70, 20, 50, 50);
        
        right = false;
    }
    
    if(p[0][2] != 0 && p[0][2] != 2) {
        fill(255, 102, 102);
        rect(120, 20, 50, 50);
        
        right = false;
    }
    
    if(p[0][3] != 0 && p[0][3] != 1) {
        fill(255, 102, 102);
        rect(170, 20, 50, 50);
        
        right = false;
    }
    
    if(p[0][8] != 0 && p[0][8] != 7) {
        fill(255, 102, 102);
        rect(420, 20, 50, 50);
        
        right = false;
    }
    
    if(p[1][2] != 0 && p[1][2] != 4) {
        fill(255, 102, 102);
        rect(120, 70, 50, 50);
        
        right = false;
    }
    
    if(p[1][5] != 0 && p[1][5] != 5) {
        fill(255, 102, 102);
        rect(270, 70, 50, 50);
        
        right = false;
    }
    
    if(p[1][7] != 0 && p[1][7] != 8) {
        fill(255, 102, 102);
        rect(370, 70, 50, 50);
        
        right = false;
    }
    
    if(p[2][0] != 0 && p[2][0] != 9) {
        fill(255, 102, 102);
        rect(20, 120, 50, 50);
        
        right = false;
    }
    
    if(p[2][2] != 0 && p[2][0] != 6) {
        fill(255, 102, 102);
        rect(120, 120, 50, 50);
        
        right = false;
    }
    
    if(p[2][3] != 0 && p[2][3] != 8) {
        fill(255, 102, 102);
        rect(170, 120, 50, 50);
        
        right = false;
    }
    
    if(p[2][5] != 0 && p[2][5] != 7) {
        fill(255, 102, 102);
        rect(270, 120, 50, 50);
        
        right = false;
    }
    
    if(p[2][6] != 0 && p[2][6] != 1) {
        fill(255, 102, 102);
        rect(320, 120, 50, 50);
        
        right = false;
    }
    
    if(p[2][8] != 0 && p[2][8] != 5) {
        fill(255, 102, 102);
        rect(420, 120, 50, 50);
        
        right = false;
    }
    
    if(p[3][1] != 0 && p[3][1] != 6) {
        fill(255, 102, 102);
        rect(70, 170, 50, 50);
        
        right = false;
    }
    
    if(!right) {
        fill(255, 0, 0);
        text("Something isn't right in the highlighted cell(s).", 500, 400);
    }
}

boolean checkBox(int number) {
    int sum = 0;
    
    if(number == 0) {
        for(int i = 0; i < 3; i++) {
            for(int j = 0; j < 3; j++) {
                sum += p[i][j];
            }
        }
    } else if(number == 1) {
        for(int i = 0; i < 3; i++) {
            for(int j = 3; j < 6; j++) {
                sum += p[i][j];
            }
        }
    } else if(number == 2) {
        for(int i = 0; i < 3; i++) {
            for(int j = 6; j < 9; j++) {
                sum += p[i][j];
            }
        }
    } else if(number == 3) {
        for(int i = 3; i < 6; i++) {
            for(int j = 0; j < 3; j++) {
                sum += p[i][j];
            }
        }
    } else if(number == 4) {
        for(int i = 3; i < 6; i++) {
            for(int j = 3; j < 6; j++) {
                sum += p[i][j];
            }
        }
    } else if(number == 5) {
        for(int i = 3; i < 6; i++) {
            for(int j = 6; j < 9; j++) {
                sum += p[i][j];
            }
        }
    } else if(number == 6) {
        for(int i = 6; i < 9; i++) {
            for(int j = 0; j < 3; j++) {
                sum += p[i][j];
            }
        }
    } else if(number == 7) {
        for(int i = 6; i < 9; i++) {
            for(int j = 3; j < 6; j++) {
                sum += p[i][j];
            }
        }
    } else if(number == 8) {
        for(int i = 6; i < 9; i++) {
            for(int j = 6; j < 9; j++) {
                sum += p[i][j];
            }
        }
    }
    
    if(sum == 45) {
        return true;
    } else {
        return false;
    }
}

boolean checkColumn(int number) {
    int sum = 0;
    
    for(int i = 0; i < p.length; i++) {
        sum += p[i][num];
    }
    
    if(sum == 45) {
        return true;
    } else {
        return false;
    }
}

boolean checkCompletion() {
    for(int i = 0; i < p.length; i++) {
        for(int j = 0; j < p[i].length; j++) {
            if(p[i][j] == 0) {
                i = p.length;
                j = p[i].length;

                return false;
            }
        }
    }
    
    return true;
}

boolean checkRow(int number) {
    int sum = 0;
    
    for(int i = 0; i < p[number].length; i++) {
        sum += p[number][i];
    }
    
    if(sum == 45) {
        return true;
    } else {
        return false;
    }
}

boolean checkWin() {
    for(int i = 0; i < 9; i++) {
        if(!checkRow(i) || !checkColumn(i) || !checkBox(i)) {
            i = 9;
            return false;
        }
    }
    
    return true;
}

void choosePuzzle() {
    int puzzle = (int)(random(12) + 1);
    
    println("Puzzle " + puzzle);
    
    if(puzzle == 1) {
        puzzle1();
        p1 = true;
    } else if(puzzle == 2) {
        puzzle2();
        p2 = true;
    } else if(puzzle == 3) {
        puzzle3();
        p3 = true;
    } else if(puzzle == 4) {
        puzzle4();
        p4 = true;
    } else if(puzzle == 5) {
        puzzle5();
        p5 = true;
    } else if(puzzle == 6) {
        puzzle6();
        p6 = true;
    } else if(puzzle == 7) {
        puzzle7();
        p7 = true;
    } else if(puzzle == 8) {
        puzzle8();
        p8 = true;
    } else if(puzzle == 9) {
        puzzle9();
        p9 = true;
    } else if(puzzle == 10) {
        puzzle10();
        p10 = true;
    } else if(puzzle == 11) {
        puzzle11();
        p11 = true;
    } else if(puzzle == 12) {
        puzzle12();
        p12 = true;
    }
}

void completed() {
    if(checkWin()) {
        textSize(20);
        fill(0, 128, 0);
        text("Congratulations! You solved the puzzle", 500, 400);
        text("correctly. 😃", 500, 430);
    } else {
        textSize(20);
        fill(255, 0, 0);
        text("😞 Sorry! Your solution to this puzzle is", 500, 430);
        text("incorrect. Please try again!", 500, 460);
    }
}

void displayBoard() {
    textSize(30); // sets the text size to 30
    fill(0); // sets the text color to black
    
    int x = 37;
    int y = 55;
    
    for(int i = 0; i < p.length; i++) {
        for(int j = 0; j < p[i].length; j++) {
            if(p[i][j] != 0) {
                text(str(p[i][j]), x, y);
            }
            
            x += 50;
        }
        
        x = 37;
        y += 50;
    }
}

void getCell(int x, int y) {
    if(x > 20 && x < 70) {
        col = 0;
    } else if(x < 120) {
        col = 1;
    } else if(x < 170) {
        col = 2;
    } else if(x < 220) {
        col = 3;
    } else if(x < 270) {
        col = 4;
    } else if(x < 320) {
        col = 5;
    } else if(x < 370) {
        col = 6;
    } else if(x < 420) {
        col = 7;
    } else if(x < 470) {
        col = 8;
    }
    
    if(y > 20 && y < 70) {
        row = 0;
    } else if(y < 120) {
        row = 1;
    } else if(y < 170) {
        row = 2;
    } else if(y < 220) {
        row = 3;
    } else if(y < 270) {
        row = 4;
    } else if(y < 320) {
        row = 5;
    } else if(y < 370) {
        row = 6;
    } else if(y < 420) {
        row = 7;
    } else if(y < 470) {
        row = 8;
    }
}

void grid() {
    background(255);
    fill(255);
    
    strokeWeight(9); // thick lines
    
    // outer box
    line(20, 20, 20, 470);
    line(20, 20, 470, 20);
    line(470, 470, 470, 20);
    line(470, 470, 20, 470);
    
    strokeWeight(3); // thin lines
    
    int x = 20;
    int y = 20;
    int w = 50;
    int h = 50;
    
    int[][] cells = new int[9][9];
    
    for(int i = 0; i < 9; i++) {
        for(int j = 0; j < 9; j++) {
            rect(x, y, w, h);
            x += 50;
        }
        
        x = 20;
        y += 50;
    }
    
    strokeWeight(7); // thick lines for 3x3 boxes
    
    // separating for 3x3 boxes
    line(20, 170, 470, 170); // top horizontal line
    line(20, 320, 470, 320); // bottom horizontal line
    line(170, 20, 170, 470); // left vertical line
    line(320, 20, 320, 470); // right vertical line
}

void instructions() {
    textSize(20);
    fill(0);
    
    for(int i = 0; i < 4; i++) {
        text("Instructions", 500, 50);
    }
    
    strokeWeight(3);
    line(500, 55, 602, 55);
    
    int ty1 = 85; // y position of the first line of the first paragraph
    int ty2 = 210; // y position of the first line of the second paragraph
    int ty3 = ty2 + 100; // y position of the first line of the third paragraph
    
    text("Using the numbers 1 through 9, fill in the grid", 500, ty1);
    text("so that each row, column, and 3x3 box ", 500, ty1 + 25);
    text("contains the each of the nine numbers only", 500, ty1 + 50);
    text("once.", 500, ty1 + 75);
    
    text("To select a cell, hover over a desired cell and ", 500, ty2);
    text("click on it. If you made a mistake, press", 500, ty2 + 25);
    text("0 to get rid of the number and clear the cell.", 500, ty2 + 50);
    
    text("If you want to change the puzzle, please", 500, ty3);
    text("press the r key.", 500, ty3 + 25);
}

void keyPressed() {
    if (key == '0') {
        num = 0;
        updateArray();
    } else if(key == '1') {
        num = 1;
        updateArray();
    } else if(key == '2') {
        num = 2;
        updateArray();
    } else if(key == '3') {
        num = 3;
        updateArray();
    } else if(key == '4') {
        num = 4;
        updateArray();
    } else if(key == '5') {
        num = 5;
        updateArray();
    } else if(key == '6') {
        num = 6;
        updateArray();
    } else if(key == '7') {
        num = 7;
        updateArray();
    } else if(key == '8') {
        num = 8;
        updateArray();
    } else if(key == '9') {
        num = 9;
        updateArray();
    } else if(key == 'r' || key == 'R') {
        setup();
    }
}

void mousePressed() {
    num = 0;
    getCell(mouseX, mouseY);
}

void puzzle1() {
    // www.websudoku.com – Evil Puzzle 124
    
    p[0][5] = 3;
    p[0][8] = 6;
    p[1][3] = 7;
    p[1][8] = 9;
    p[2][2] = 4;
    p[2][4] = 6;
    p[2][7] = 8;
    p[2][8] = 2;
    p[3][4] = 9;
    p[3][7] = 7;
    p[4][1] = 1;
    p[4][2] = 6;
    p[4][6] = 8;
    p[4][7] = 5;
    p[5][1] = 2;
    p[5][4] = 3;
    p[6][0] = 2;
    p[6][1] = 8;
    p[6][4] = 5;
    p[6][6] = 6;
    p[7][0] = 3;
    p[7][5] = 8;
    p[8][0] = 7;
    p[8][3] = 1;
    
    displayBoard();
}

void puzzle2() {
    // www.websudoku.com – Evil Puzzle 6,101,976,392
    
    p[0][4] = 6;
    p[0][5] = 1;
    p[0][8] = 5;
    p[1][0] = 8;
    p[1][4] = 5;
    p[2][6] = 8;
    p[2][7] = 4;
    p[2][8] = 7;
    p[3][1] = 5;
    p[3][6] = 9;
    p[4][0] = 6;
    p[4][3] = 9;
    p[4][5] = 4;
    p[4][8] = 8;
    p[5][2] = 3;
    p[5][7] = 1;
    p[6][0] = 7;
    p[6][1] = 9;
    p[6][2] = 1;
    p[7][4] = 8;
    p[7][8] = 2;
    p[8][0] = 5;
    p[8][3] = 7;
    p[8][4] = 3;
    
    displayBoard();
}

void puzzle3() {
    // www.websudoku.com – Evil Puzzle 8,655,032,120
    
    p[0][5] = 1;
    p[0][6] = 2;
    p[0][7] = 6;
    p[1][6] = 7;
    p[2][2] = 5;
    p[2][4] = 3;
    p[2][7] = 8;
    p[3][0] = 2;
    p[3][1] = 3;
    p[3][2] = 6;
    p[3][3] = 4;
    p[3][7] = 9;
    p[4][3] = 6;
    p[4][5] = 9;
    p[5][1] = 8;
    p[5][5] = 2;
    p[5][6] = 4;
    p[5][7] = 7;
    p[5][8] = 6;
    p[6][1] = 5;
    p[6][4] = 4;
    p[6][6] = 1;
    p[7][2] = 3;
    p[8][1] = 9;
    p[8][2] = 8;
    p[8][3] = 7;
    
    displayBoard();
}

void puzzle4() {
    // www.websudoku.com – Evil Puzzle 8,895,091,461
    
    p[0][3] = 8;
    p[1][4] = 7;
    p[1][6] = 2;
    p[1][8] = 9;
    p[2][5] = 6;
    p[2][7] = 1;
    p[2][8] = 4;
    p[3][1] = 8;
    p[3][2] = 2;
    p[3][7] = 7;
    p[4][1] = 4;
    p[4][3] = 3;
    p[4][4] = 9;
    p[4][5] = 2;
    p[4][7] = 8;
    p[5][1] = 5;
    p[5][6] = 9;
    p[5][7] = 2;
    p[6][0] = 6;
    p[6][1] = 3;
    p[6][3] = 5;
    p[7][0] = 5;
    p[7][2] = 9;
    p[7][4] = 1;
    p[8][5] = 4;
    
    displayBoard();
}

void puzzle5() {
    // www.websudoku.com – Hard Puzzle 3,864,710,980
    
    p[0][1] = 9;
    p[0][2] = 5;
    p[0][4] = 3;
    p[0][5] = 6;
    p[1][0] = 4;
    p[2][0] = 1;
    p[2][3] = 8;
    p[2][4] = 5;
    p[2][6] = 6;
    p[2][7] = 7;
    p[3][0] = 2;
    p[3][2] = 1;
    p[4][0] = 9;
    p[4][1] = 5;
    p[4][7] = 8;
    p[4][8] = 6;
    p[5][6] = 2;
    p[5][8] = 1;
    p[6][1] = 7;
    p[6][2] = 8;
    p[6][4] = 9;
    p[6][5] = 1;
    p[6][8] = 4;
    p[7][8] = 3;
    p[8][3] = 2;
    p[8][4] = 8;
    p[8][6] = 9;
    p[8][7] = 6;
    
    displayBoard();
}

void puzzle6() {
    // www.websudoku.com – Hard Puzzle 9,934,487,744
    
    p[0][0] = 6;
    p[0][3] = 5;
    p[0][4] = 3;
    p[0][8] = 7;
    p[1][0] = 4;
    p[1][2] = 1;
    p[1][7] = 2;
    p[2][1] = 9;
    p[2][3] = 1;
    p[2][5] = 4;
    p[3][3] = 8;
    p[3][7] = 9;
    p[4][0] = 7;
    p[4][2] = 4;
    p[4][6] = 8;
    p[4][8] = 2;
    p[5][1] = 8;
    p[5][5] = 5;
    p[6][3] = 9;
    p[6][5] = 1;
    p[6][7] = 3;
    p[7][1] = 3;
    p[7][6] = 9;
    p[7][8] = 5;
    p[8][0] = 1;
    p[8][4] = 5;
    p[8][5] = 3;
    p[8][8] = 6;
    
    displayBoard();
}

void puzzle7() {
    // www.websudoku.com – Medium Puzzle 2,981,621,299
    
    p[0][0] = 7;
    p[0][4] = 2;
    p[0][5] = 9;
    p[0][7] = 1;
    p[1][0] = 2;
    p[1][4] = 4;
    p[1][5] = 8;
    p[2][0] = 8;
    p[2][1] = 3;
    p[2][4] = 6;
    p[2][6] = 2;
    p[3][0] = 4;
    p[3][2] = 9;
    p[3][5] = 6;
    p[3][8] = 8;
    p[4][0] = 3;
    p[4][8] = 1;
    p[5][0] = 5;
    p[5][3] = 4;
    p[5][6] = 6;
    p[5][8] = 3;
    p[6][2] = 2;
    p[6][4] = 9;
    p[6][7] = 3;
    p[6][8] = 7;
    p[7][3] = 6;
    p[7][4] = 1;
    p[7][8] = 2;
    p[8][1] = 4;
    p[8][3] = 2;
    p[8][4] = 7;
    p[8][8] = 6;
    
    displayBoard();
}

void puzzle8() {
    // www.websudoku.com – Medium Puzzle 3,075,869,438
    
    p[0][1] = 4;
    p[0][2] = 1;
    p[0][6] = 8;
    p[1][7] = 5;
    p[2][1] = 2;
    p[2][3] = 7;
    p[2][5] = 8;
    p[2][6] = 4;
    p[2][7] = 9;
    p[3][0] = 2;
    p[3][4] = 7;
    p[3][5] = 9;
    p[3][7] = 6;
    p[4][2] = 9;
    p[4][3] = 5;
    p[4][4] = 3;
    p[4][5] = 2;
    p[4][6] = 1;
    p[5][1] = 3;
    p[5][3] = 6;
    p[5][4] = 1;
    p[5][8] = 9;
    p[6][1] = 1;
    p[6][2] = 2;
    p[6][3] = 4;
    p[6][5] = 5;
    p[6][7] = 8;
    p[7][1] = 8;
    p[8][2] = 5;
    p[8][5] = 1;
    p[8][7] = 4;
    
    displayBoard();
}

void puzzle9() {
    // www.websudoku.com – Medium Puzzle 6,569,172,006
    
    p[0][3] = 6;
    p[0][7] = 3;
    p[0][1] = 1;
    p[1][8] = 1;
    p[1][3] = 5;
    p[1][6] = 2;
    p[1][7] = 9;
    p[2][3] = 2;
    p[2][6] = 6;
    p[3][0] = 5;
    p[3][4] = 6;
    p[3][5] = 2;
    p[4][1] = 6;
    p[4][2] = 9;
    p[4][4] = 8;
    p[4][6] = 7;
    p[4][7] = 4;
    p[5][3] = 3;
    p[5][4] = 7;
    p[5][8] = 5;
    p[6][2] = 6;
    p[6][5] = 9;
    p[7][1] = 3;
    p[7][2] = 4;
    p[7][5] = 1;
    p[7][7] = 5;
    p[8][0] = 7;
    p[8][1] = 5;
    p[8][5] = 6;
    
    displayBoard();
}

void puzzle10() {
    // www.websudoku.com – Medium Puzzle 8,136,223,360
    
    p[0][2] = 7;
    p[0][5] = 6;
    p[1][1] = 3;
    p[1][5] = 5;
    p[2][0] = 5;
    p[2][1] = 6;
    p[2][2] = 4;
    p[2][4] = 1;
    p[2][7] = 2;
    p[3][0] = 2;
    p[3][3] = 5;
    p[3][4] = 6;
    p[3][8] = 7;
    p[4][2] = 5;
    p[4][6] = 6;
    p[5][0] = 8;
    p[5][4] = 7;
    p[5][5] = 2;
    p[5][8] = 3;
    p[6][1] = 8;
    p[6][4] = 5;
    p[6][6] = 7;
    p[6][7] = 9;
    p[6][8] = 4;
    p[7][3] = 9;
    p[7][7] = 3;
    p[8][3] = 3;
    p[8][6] = 5;
    
    displayBoard();
}

void puzzle11() {
    // www.websudoku.com – Easy Puzzle 314,794,788
    
    p[0][5] = 2;
    p[0][6] = 5;
    p[0][7] = 8;
    p[1][0] = 1;
    p[1][2] = 2;
    p[1][8] = 7;
    p[2][3] = 9;
    p[2][4] = 7;
    p[2][5] = 3;
    p[2][6] = 2;
    p[2][7] = 6;
    p[3][3] = 5;
    p[3][4] = 8;
    p[3][5] = 4;
    p[3][6] = 3;
    p[3][7] = 1;
    p[4][0] = 2;
    p[4][3] = 6;
    p[4][5] = 7;
    p[4][8] = 5;
    p[5][1] = 5;
    p[5][2] = 8;
    p[5][3] = 2;
    p[5][4] = 1;
    p[5][5] = 9;
    p[6][1] = 7;
    p[6][2] = 9;
    p[6][3] = 8;
    p[6][4] = 2;
    p[6][5] = 5;
    p[7][0] = 5;
    p[7][6] = 7;
    p[7][8] = 9;
    p[8][1] = 2;
    p[8][2] = 3;
    p[8][3] = 7;
    
    displayBoard();
}

void puzzle12() {
    // www.websudoku.com – Easy Puzzle 2,006,736,503
    
    p[0][0] = 5;
    p[0][4] = 9;
    p[0][5] = 4;
    p[0][6] = 6;
    p[0][7] = 3;
    p[1][0] = 1;
    p[1][1] = 7;
    p[1][3] = 3;
    p[1][4] = 6;
    p[1][6] = 9;
    p[1][8] = 2;
    p[2][1] = 3;
    p[2][4] = 2;
    p[2][7] = 4;
    p[3][0] = 7;
    p[3][8] = 8;
    p[4][0] = 2;
    p[4][3] = 7;
    p[4][5] = 1;
    p[4][8] = 6;
    p[5][0] = 3;
    p[5][8] = 4;
    p[6][1] = 9;
    p[6][4] = 7;
    p[6][7] = 2;
    p[7][0] = 4;
    p[7][2] = 1;
    p[7][4] = 8;
    p[7][5] = 9;
    p[7][7] = 6;
    p[7][8] = 3;
    p[8][1] = 2;
    p[8][2] = 7;
    p[8][3] = 4;
    p[8][4] = 1;
    p[8][8] = 9;
    
    displayBoard();
}

void updateAndDisplay() {
    num = 0;
    
    grid();
    
    if(p1) {
        check1();
    } else if(p2) {
        check2();
    } else if(p3) {
        check3();
    } else if(p4) {
        check4();
    } else if(p5) {
        check5();
    } else if(p6) {
        check6();
    } else if(p7) {
        check7();
    } else if(p8) {
        check8();
    } else if(p9) {
        check9();
    } else if(p10) {
        check10();
    } else if(p11) {
        check11();
    } else if(p12) {
        check12();
    }
    
    displayBoard();
    
    instructions();
    
    if(checkCompletion()) {
        completed();
    }
}

void updateArray() {
    p[row][col] = num;

    updateAndDisplay();
}

void setup() {
    size(900, 500);
    background(255, 255, 255);
    
    p1 = false;
    p2 = false;
    p3 = false;
    p4 = true;
    p5 = false;
    p6 = false;
    p7 = false;
    p8 = false;
    p9 = false;
    p10 = false;
    p11 = false;
    
    for(int i = 0; i < p.length; i++) {
        for(int j = 0; j < p[i].length; j++) {
            p[i][j] = 0;
        }
    }
    
    grid();
    instructions();
    choosePuzzle();
}
// Out:
// <div id="canvas_div_4">
//   <b>Sketch #4:</b><br/>
//   <canvas id="canvas_4"></canvas><br/>
// </div>
// <div id="controls_div_4">
//   <button id="run_button_4" onclick="startSketch('4');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_4" onclick="pauseSketch('4');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_4" onclick="setupSketch('4');">
//     setup()
//   </button>
//   <button id="draw_button_4" onclick="drawSketch('4');">
//     draw()
//   </button>
// </div>
// <b>Sketch #4 state:</b> <span id="state_4">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...
